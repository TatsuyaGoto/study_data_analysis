# %% [markdown]
# # タイタニックの生存予測
# https://signate.jp/competitions/102/

# %% [markdown]
# ## ライブラリのインストール

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import lightgbm as lgb
import optuna.integration.lightgbm as lgb_o
from sklearn.metrics import roc_auc_score

from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## データの読み込み

# %%
train = pd.read_csv("train.tsv", sep="\t", index_col=0) # 学習用データ
test = pd.read_csv("test.tsv", sep="\t", index_col=0)   # 評価用データ
sample_submit = pd.read_csv("sample_submit.tsv", sep="\t", index_col=0, header=None) # 応募用サンプルファイル

# %%
#skleanのver次第でLabelEncoderでエラーが出る可能性があるため追加
train.dropna(subset=["embarked"], inplace=True)
#train = train[~train["embarked"].isnull()]

# %% [markdown]
# ## データの前処理

# %%
le = LabelEncoder()
train["sex"] = le.fit_transform(train["sex"])
le.classes_
# Out:
# array(['female', 'male'], dtype=object)

# %%
le = LabelEncoder()
train["embarked"] = le.fit_transform(train["embarked"])
le.classes_
# Out:
# array(['C', 'Q', 'S'], dtype=object)

# %% [markdown]
# ## 年齢の情報を追加

# %%
train["age"].mean()
# Out:
# 29.0954469273743

# %%
train["age"] = train["age"].fillna(train["age"].mean())

# %% [markdown]
# ## 年齢層の情報を追加

# %%
bins = [0, 20, 40, 60, 80]
train["age_label"] = pd.cut(train["age"], bins=bins, labels=False)
train
# Out:
#      survived  pclass  sex        age  sibsp  parch     fare  embarked
# id
# 3           1       1    0  35.000000      1      0  53.1000         2  \
# 4           0       3    1  35.000000      0      0   8.0500         2
# 7           0       3    1   2.000000      3      1  21.0750         2
# 9           1       2    0  14.000000      1      0  30.0708         0
# 11          1       1    0  58.000000      0      0  26.5500         2
# ..        ...     ...  ...        ...    ...    ...      ...       ...
# 873         0       3    1  47.000000      0      0   9.0000         2
# 874         1       2    0  28.000000      1      0  24.0000         0
# 879         1       1    0  56.000000      0      1  83.1583         0
# 884         0       3    1  25.000000      0      0   7.0500         2
# 888         0       3    0  29.095447      1      2  23.4500         2
#
#      age_label
# id
# 3            1
# 4            1
# 7            0
# 9            0
# 11           2
# ..         ...
# 873          2
# 874          1
# 879          2
# 884          1
# 888          1
#
# [443 rows x 9 columns]

# %% [markdown]
# ## 家族の情報を追加

# %%
train["family"] = train["sibsp"] + train["parch"] +1
train
# Out:
#      survived  pclass  sex        age  sibsp  parch     fare  embarked
# id
# 3           1       1    0  35.000000      1      0  53.1000         2  \
# 4           0       3    1  35.000000      0      0   8.0500         2
# 7           0       3    1   2.000000      3      1  21.0750         2
# 9           1       2    0  14.000000      1      0  30.0708         0
# 11          1       1    0  58.000000      0      0  26.5500         2
# ..        ...     ...  ...        ...    ...    ...      ...       ...
# 873         0       3    1  47.000000      0      0   9.0000         2
# 874         1       2    0  28.000000      1      0  24.0000         0
# 879         1       1    0  56.000000      0      1  83.1583         0
# 884         0       3    1  25.000000      0      0   7.0500         2
# 888         0       3    0  29.095447      1      2  23.4500         2
#
#      age_label  family
# id
# 3            1       2
# 4            1       1
# 7            0       5
# 9            0       2
# 11           2       1
# ..         ...     ...
# 873          2       1
# 874          1       2
# 879          2       2
# 884          1       1
# 888          1       4
#
# [443 rows x 10 columns]

# %% [markdown]
# ## LightGBMで作成

# %% [markdown]
# https://smart-hint.com/ml/gbdt-image/

# %%
data = train.drop(["survived"], axis=1)
target = train["survived"]

# %%
params = {
    "metric": "auc",
    "objective": "binary",
    #'learning_rate': 0.01,
    'min_child_samples': 5,
    #'force_col_wise': True
}

# %%
kf = KFold(n_splits=5, shuffle=True, random_state=1)

# %%
auc_ave = []

for train_index, valid_index in kf.split(data):
    
    X_train = data.iloc[train_index]
    X_valid = data.iloc[valid_index]
    
    y_train = target.iloc[train_index]
    y_valid = target.iloc[valid_index]
    
    lgb_train = lgb.Dataset(X_train, y_train)
    lgb_eval = lgb.Dataset(X_valid, y_valid)
    
    lgbm = lgb.train(
        params,
        lgb_train,
        valid_sets=lgb_eval,
        num_boost_round=1000,
        early_stopping_rounds=50,
        #verbose_eval=False
    )
    
    #y_train_pred = lgbm.predict(x_train)
    y_pred = lgbm.predict(X_valid)
    
    auc = roc_auc_score(y_valid, y_pred)
    auc_ave.append(auc)
    
    print(auc)

print("ave:{:.3f}".format(np.mean(auc_ave)))
# Out:
# [LightGBM] [Info] Number of positive: 143, number of negative: 211
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000536 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 158
# [LightGBM] [Info] Number of data points in the train set: 354, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.403955 -> initscore=-0.389014
# [LightGBM] [Info] Start training from score -0.389014
# [1]	valid_0's auc: 0.910428
# Training until validation scores don't improve for 50 rounds
# [2]	valid_0's auc: 0.912567
# [3]	valid_0's auc: 0.916043
# [4]	valid_0's auc: 0.908556
# [5]	valid_0's auc: 0.912032
# [6]	valid_0's auc: 0.91016
# [7]	valid_0's auc: 0.923529
# [8]	valid_0's auc: 0.924064
# [9]	valid_0's auc: 0.924064
# [10]	valid_0's auc: 0.925936
# [11]	valid_0's auc: 0.926471
# [12]	valid_0's auc: 0.924866
# [13]	valid_0's auc: 0.926471
# [14]	valid_0's auc: 0.925936
# [15]	valid_0's auc: 0.924332
# [16]	valid_0's auc: 0.923262
# [17]	valid_0's auc: 0.921123
# [18]	valid_0's auc: 0.916043
# [19]	valid_0's auc: 0.916578
# [20]	valid_0's auc: 0.912834
# [21]	valid_0's auc: 0.909626
# [22]	valid_0's auc: 0.909091
# [23]	valid_0's auc: 0.908556
# [24]	valid_0's auc: 0.908021
# [25]	valid_0's auc: 0.907487
# [26]	valid_0's auc: 0.904813
# [27]	valid_0's auc: 0.900535
# [28]	valid_0's auc: 0.902674
# [29]	valid_0's auc: 0.903743
# [30]	valid_0's auc: 0.901604
# [31]	valid_0's auc: 0.90107
# [32]	valid_0's auc: 0.896257
# [33]	valid_0's auc: 0.895722
# [34]	valid_0's auc: 0.894652
# [35]	valid_0's auc: 0.891979
# [36]	valid_0's auc: 0.88984
# [37]	valid_0's auc: 0.888235
# [38]	valid_0's auc: 0.889305
# [39]	valid_0's auc: 0.892513
# [40]	valid_0's auc: 0.889305
# [41]	valid_0's auc: 0.889305
# [42]	valid_0's auc: 0.88877
# [43]	valid_0's auc: 0.890374
# [44]	valid_0's auc: 0.891444
# [45]	valid_0's auc: 0.890909
# [46]	valid_0's auc: 0.890909
# [47]	valid_0's auc: 0.890909
# [48]	valid_0's auc: 0.890909
# [49]	valid_0's auc: 0.890909
# [50]	valid_0's auc: 0.893048
# [51]	valid_0's auc: 0.893048
# [52]	valid_0's auc: 0.891979
# [53]	valid_0's auc: 0.891979
# [54]	valid_0's auc: 0.893048
# [55]	valid_0's auc: 0.890909
# [56]	valid_0's auc: 0.891979
# [57]	valid_0's auc: 0.88984
# [58]	valid_0's auc: 0.887701
# [59]	valid_0's auc: 0.886096
# [60]	valid_0's auc: 0.88984
# [61]	valid_0's auc: 0.88984
# Early stopping, best iteration is:
# [11]	valid_0's auc: 0.926471
# 0.9264705882352942
# [LightGBM] [Info] Number of positive: 133, number of negative: 221
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000094 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 158
# [LightGBM] [Info] Number of data points in the train set: 354, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.375706 -> initscore=-0.507814
# [LightGBM] [Info] Start training from score -0.507814
# [1]	valid_0's auc: 0.836616
# Training until validation scores don't improve for 50 rounds
# [2]	valid_0's auc: 0.836616
# [3]	valid_0's auc: 0.830303
# [4]	valid_0's auc: 0.843939
# [5]	valid_0's auc: 0.826263
# [6]	valid_0's auc: 0.830808
# [7]	valid_0's auc: 0.837879
# [8]	valid_0's auc: 0.838636
# [9]	valid_0's auc: 0.842929
# [10]	valid_0's auc: 0.847475
# [11]	valid_0's auc: 0.846465
# [12]	valid_0's auc: 0.845707
# [13]	valid_0's auc: 0.840152
# [14]	valid_0's auc: 0.840909
# [15]	valid_0's auc: 0.841919
# [16]	valid_0's auc: 0.841919
# [17]	valid_0's auc: 0.841414
# [18]	valid_0's auc: 0.840909
# [19]	valid_0's auc: 0.835354
# [20]	valid_0's auc: 0.831061
# [21]	valid_0's auc: 0.831061
# [22]	valid_0's auc: 0.835101
# [23]	valid_0's auc: 0.833081
# [24]	valid_0's auc: 0.832071
# [25]	valid_0's auc: 0.827525
# [26]	valid_0's auc: 0.829798
# [27]	valid_0's auc: 0.833081
# [28]	valid_0's auc: 0.831566
# [29]	valid_0's auc: 0.834596
# [30]	valid_0's auc: 0.831061
# [31]	valid_0's auc: 0.829545
# [32]	valid_0's auc: 0.832576
# [33]	valid_0's auc: 0.833586
# [34]	valid_0's auc: 0.837626
# [35]	valid_0's auc: 0.835101
# [36]	valid_0's auc: 0.836616
# [37]	valid_0's auc: 0.836111
# [38]	valid_0's auc: 0.840152
# [39]	valid_0's auc: 0.839646
# [40]	valid_0's auc: 0.839646
# [41]	valid_0's auc: 0.843687
# [42]	valid_0's auc: 0.843182
# [43]	valid_0's auc: 0.846212
# [44]	valid_0's auc: 0.844697
# [45]	valid_0's auc: 0.845202
# [46]	valid_0's auc: 0.841162
# [47]	valid_0's auc: 0.842677
# [48]	valid_0's auc: 0.846717
# [49]	valid_0's auc: 0.845707
# [50]	valid_0's auc: 0.845707
# [51]	valid_0's auc: 0.846717
# [52]	valid_0's auc: 0.845202
# [53]	valid_0's auc: 0.845707
# [54]	valid_0's auc: 0.845707
# [55]	valid_0's auc: 0.845707
# [56]	valid_0's auc: 0.845202
# [57]	valid_0's auc: 0.844697
# [58]	valid_0's auc: 0.846717
# [59]	valid_0's auc: 0.845707
# [60]	valid_0's auc: 0.845202
# Early stopping, best iteration is:
# [10]	valid_0's auc: 0.847475
# 0.8474747474747475
# [LightGBM] [Info] Number of positive: 146, number of negative: 208
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000127 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 155
# [LightGBM] [Info] Number of data points in the train set: 354, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.412429 -> initscore=-0.353931
# [LightGBM] [Info] Start training from score -0.353931
# [1]	valid_0's auc: 0.818966
# Training until validation scores don't improve for 50 rounds
# [2]	valid_0's auc: 0.815072
# [3]	valid_0's auc: 0.81257
# [4]	valid_0's auc: 0.818687
# [5]	valid_0's auc: 0.818131
# [6]	valid_0's auc: 0.854839
# [7]	valid_0's auc: 0.845384
# [8]	valid_0's auc: 0.841212
# [9]	valid_0's auc: 0.845384
# [10]	valid_0's auc: 0.840378
# [11]	valid_0's auc: 0.83871
# [12]	valid_0's auc: 0.844271
# [13]	valid_0's auc: 0.843715
# [14]	valid_0's auc: 0.854283
# [15]	valid_0's auc: 0.848721
# [16]	valid_0's auc: 0.858176
# [17]	valid_0's auc: 0.868743
# [18]	valid_0's auc: 0.862625
# [19]	valid_0's auc: 0.860957
# [20]	valid_0's auc: 0.8604
# [21]	valid_0's auc: 0.862069
# [22]	valid_0's auc: 0.85762
# [23]	valid_0's auc: 0.860957
# [24]	valid_0's auc: 0.862069
# [25]	valid_0's auc: 0.861513
# [26]	valid_0's auc: 0.86485
# [27]	valid_0's auc: 0.865406
# [28]	valid_0's auc: 0.863181
# [29]	valid_0's auc: 0.86485
# [30]	valid_0's auc: 0.855951
# [31]	valid_0's auc: 0.855951
# [32]	valid_0's auc: 0.852058
# [33]	valid_0's auc: 0.849833
# [34]	valid_0's auc: 0.849833
# [35]	valid_0's auc: 0.851502
# [36]	valid_0's auc: 0.845384
# [37]	valid_0's auc: 0.84594
# [38]	valid_0's auc: 0.845384
# [39]	valid_0's auc: 0.843159
# [40]	valid_0's auc: 0.842047
# [41]	valid_0's auc: 0.840934
# [42]	valid_0's auc: 0.839822
# [43]	valid_0's auc: 0.836763
# [44]	valid_0's auc: 0.836207
# [45]	valid_0's auc: 0.836763
# [46]	valid_0's auc: 0.838432
# [47]	valid_0's auc: 0.835651
# [48]	valid_0's auc: 0.838432
# [49]	valid_0's auc: 0.835095
# [50]	valid_0's auc: 0.836207
# [51]	valid_0's auc: 0.836763
# [52]	valid_0's auc: 0.836207
# [53]	valid_0's auc: 0.833982
# [54]	valid_0's auc: 0.835651
# [55]	valid_0's auc: 0.835651
# [56]	valid_0's auc: 0.835651
# [57]	valid_0's auc: 0.835651
# [58]	valid_0's auc: 0.837875
# [59]	valid_0's auc: 0.838988
# [60]	valid_0's auc: 0.835095
# [61]	valid_0's auc: 0.833426
# [62]	valid_0's auc: 0.836207
# [63]	valid_0's auc: 0.836207
# [64]	valid_0's auc: 0.836207
# [65]	valid_0's auc: 0.832314
# [66]	valid_0's auc: 0.834538
# [67]	valid_0's auc: 0.831201
# Early stopping, best iteration is:
# [17]	valid_0's auc: 0.868743
# 0.8687430478309233
# [LightGBM] [Info] Number of positive: 142, number of negative: 213
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000086 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 159
# [LightGBM] [Info] Number of data points in the train set: 355, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.400000 -> initscore=-0.405465
# [LightGBM] [Info] Start training from score -0.405465
# [1]	valid_0's auc: 0.822911
# Training until validation scores don't improve for 50 rounds
# [2]	valid_0's auc: 0.836658
# [3]	valid_0's auc: 0.855795
# [4]	valid_0's auc: 0.858491
# [5]	valid_0's auc: 0.8531
# [6]	valid_0's auc: 0.856604
# [7]	valid_0's auc: 0.853369
# [8]	valid_0's auc: 0.854447
# [9]	valid_0's auc: 0.856604
# [10]	valid_0's auc: 0.855526
# [11]	valid_0's auc: 0.854447
# [12]	valid_0's auc: 0.856065
# [13]	valid_0's auc: 0.855526
# [14]	valid_0's auc: 0.857682
# [15]	valid_0's auc: 0.863073
# [16]	valid_0's auc: 0.862534
# [17]	valid_0's auc: 0.867385
# [18]	valid_0's auc: 0.865499
# [19]	valid_0's auc: 0.866038
# [20]	valid_0's auc: 0.866577
# [21]	valid_0's auc: 0.867116
# [22]	valid_0's auc: 0.867655
# [23]	valid_0's auc: 0.865768
# [24]	valid_0's auc: 0.867385
# [25]	valid_0's auc: 0.869272
# [26]	valid_0's auc: 0.867655
# [27]	valid_0's auc: 0.867116
# [28]	valid_0's auc: 0.86496
# [29]	valid_0's auc: 0.867655
# [30]	valid_0's auc: 0.866846
# [31]	valid_0's auc: 0.861995
# [32]	valid_0's auc: 0.860916
# [33]	valid_0's auc: 0.862534
# [34]	valid_0's auc: 0.863881
# [35]	valid_0's auc: 0.863342
# [36]	valid_0's auc: 0.866038
# [37]	valid_0's auc: 0.862803
# [38]	valid_0's auc: 0.866038
# [39]	valid_0's auc: 0.871429
# [40]	valid_0's auc: 0.870889
# [41]	valid_0's auc: 0.871968
# [42]	valid_0's auc: 0.872507
# [43]	valid_0's auc: 0.870889
# [44]	valid_0's auc: 0.873046
# [45]	valid_0's auc: 0.873046
# [46]	valid_0's auc: 0.873046
# [47]	valid_0's auc: 0.870889
# [48]	valid_0's auc: 0.871968
# [49]	valid_0's auc: 0.872507
# [50]	valid_0's auc: 0.871429
# [51]	valid_0's auc: 0.871968
# [52]	valid_0's auc: 0.873585
# [53]	valid_0's auc: 0.873585
# [54]	valid_0's auc: 0.875741
# [55]	valid_0's auc: 0.874663
# [56]	valid_0's auc: 0.874663
# [57]	valid_0's auc: 0.871968
# [58]	valid_0's auc: 0.873585
# [59]	valid_0's auc: 0.873046
# [60]	valid_0's auc: 0.872507
# [61]	valid_0's auc: 0.870889
# [62]	valid_0's auc: 0.871429
# [63]	valid_0's auc: 0.871968
# [64]	valid_0's auc: 0.87035
# [65]	valid_0's auc: 0.871429
# [66]	valid_0's auc: 0.870889
# [67]	valid_0's auc: 0.872507
# [68]	valid_0's auc: 0.874663
# [69]	valid_0's auc: 0.873046
# [70]	valid_0's auc: 0.871429
# [71]	valid_0's auc: 0.871429
# [72]	valid_0's auc: 0.87035
# [73]	valid_0's auc: 0.869811
# [74]	valid_0's auc: 0.869811
# [75]	valid_0's auc: 0.87035
# [76]	valid_0's auc: 0.872507
# [77]	valid_0's auc: 0.871429
# [78]	valid_0's auc: 0.871429
# [79]	valid_0's auc: 0.873046
# [80]	valid_0's auc: 0.873046
# [81]	valid_0's auc: 0.873046
# [82]	valid_0's auc: 0.873585
# [83]	valid_0's auc: 0.873585
# [84]	valid_0's auc: 0.873585
# [85]	valid_0's auc: 0.873046
# [86]	valid_0's auc: 0.872507
# [87]	valid_0's auc: 0.871968
# [88]	valid_0's auc: 0.871429
# [89]	valid_0's auc: 0.873046
# [90]	valid_0's auc: 0.873585
# [91]	valid_0's auc: 0.873585
# [92]	valid_0's auc: 0.875202
# [93]	valid_0's auc: 0.875741
# [94]	valid_0's auc: 0.875202
# [95]	valid_0's auc: 0.873585
# [96]	valid_0's auc: 0.873046
# [97]	valid_0's auc: 0.873046
# [98]	valid_0's auc: 0.872507
# [99]	valid_0's auc: 0.873046
# [100]	valid_0's auc: 0.873585
# [101]	valid_0's auc: 0.873046
# [102]	valid_0's auc: 0.873046
# [103]	valid_0's auc: 0.871968
# [104]	valid_0's auc: 0.873046
# Early stopping, best iteration is:
# [54]	valid_0's auc: 0.875741
# 0.8757412398921832
# [LightGBM] [Info] Number of positive: 144, number of negative: 211
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000127 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 157
# [LightGBM] [Info] Number of data points in the train set: 355, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.405634 -> initscore=-0.382045
# [LightGBM] [Info] Start training from score -0.382045
# [1]	valid_0's auc: 0.742975
# Training until validation scores don't improve for 50 rounds
# [2]	valid_0's auc: 0.758402
# [3]	valid_0's auc: 0.754545
# [4]	valid_0's auc: 0.762259
# [5]	valid_0's auc: 0.755647
# [6]	valid_0's auc: 0.763361
# [7]	valid_0's auc: 0.761157
# [8]	valid_0's auc: 0.769972
# [9]	valid_0's auc: 0.773554
# [10]	valid_0's auc: 0.769146
# [11]	valid_0's auc: 0.759229
# [12]	valid_0's auc: 0.766942
# [13]	valid_0's auc: 0.760882
# [14]	valid_0's auc: 0.762534
# [15]	valid_0's auc: 0.76281
# [16]	valid_0's auc: 0.765565
# [17]	valid_0's auc: 0.758953
# [18]	valid_0's auc: 0.766667
# [19]	valid_0's auc: 0.756198
# [20]	valid_0's auc: 0.762259
# [21]	valid_0's auc: 0.763912
# [22]	valid_0's auc: 0.764738
# [23]	valid_0's auc: 0.766942
# [24]	valid_0's auc: 0.768044
# [25]	valid_0's auc: 0.763636
# [26]	valid_0's auc: 0.766942
# [27]	valid_0's auc: 0.769146
# [28]	valid_0's auc: 0.772452
# [29]	valid_0's auc: 0.771901
# [30]	valid_0's auc: 0.772452
# [31]	valid_0's auc: 0.770799
# [32]	valid_0's auc: 0.770248
# [33]	valid_0's auc: 0.772452
# [34]	valid_0's auc: 0.775207
# [35]	valid_0's auc: 0.774656
# [36]	valid_0's auc: 0.775758
# [37]	valid_0's auc: 0.775758
# [38]	valid_0's auc: 0.776033
# [39]	valid_0's auc: 0.774931
# [40]	valid_0's auc: 0.77438
# [41]	valid_0's auc: 0.774931
# [42]	valid_0's auc: 0.777135
# [43]	valid_0's auc: 0.775482
# [44]	valid_0's auc: 0.773829
# [45]	valid_0's auc: 0.774931
# [46]	valid_0's auc: 0.777135
# [47]	valid_0's auc: 0.774931
# [48]	valid_0's auc: 0.779339
# [49]	valid_0's auc: 0.780441
# [50]	valid_0's auc: 0.780441
# [51]	valid_0's auc: 0.783196
# [52]	valid_0's auc: 0.780992
# [53]	valid_0's auc: 0.781543
# [54]	valid_0's auc: 0.780441
# [55]	valid_0's auc: 0.77989
# [56]	valid_0's auc: 0.780441
# [57]	valid_0's auc: 0.778788
# [58]	valid_0's auc: 0.779339
# [59]	valid_0's auc: 0.779339
# [60]	valid_0's auc: 0.777135
# [61]	valid_0's auc: 0.77438
# [62]	valid_0's auc: 0.776033
# [63]	valid_0's auc: 0.777686
# [64]	valid_0's auc: 0.779339
# [65]	valid_0's auc: 0.777135
# [66]	valid_0's auc: 0.780441
# [67]	valid_0's auc: 0.779339
# [68]	valid_0's auc: 0.778237
# [69]	valid_0's auc: 0.777686
# [70]	valid_0's auc: 0.776584
# [71]	valid_0's auc: 0.776309
# [72]	valid_0's auc: 0.77686
# [73]	valid_0's auc: 0.77686
# [74]	valid_0's auc: 0.773003
# [75]	valid_0's auc: 0.775207
# [76]	valid_0's auc: 0.775758
# [77]	valid_0's auc: 0.774656
# [78]	valid_0's auc: 0.771901
# [79]	valid_0's auc: 0.771901
# [80]	valid_0's auc: 0.772452
# [81]	valid_0's auc: 0.771901
# [82]	valid_0's auc: 0.771901
# [83]	valid_0's auc: 0.772452
# [84]	valid_0's auc: 0.771901
# [85]	valid_0's auc: 0.770248
# [86]	valid_0's auc: 0.769146
# [87]	valid_0's auc: 0.768595
# [88]	valid_0's auc: 0.769146
# [89]	valid_0's auc: 0.769146
# [90]	valid_0's auc: 0.769697
# [91]	valid_0's auc: 0.768595
# [92]	valid_0's auc: 0.769146
# [93]	valid_0's auc: 0.768044
# [94]	valid_0's auc: 0.766391
# [95]	valid_0's auc: 0.764187
# [96]	valid_0's auc: 0.762534
# [97]	valid_0's auc: 0.761433
# [98]	valid_0's auc: 0.763636
# [99]	valid_0's auc: 0.766391
# [100]	valid_0's auc: 0.764187
# [101]	valid_0's auc: 0.763085
# Early stopping, best iteration is:
# [51]	valid_0's auc: 0.783196
# 0.7831955922865014
# ave:0.860

# %% [markdown]
# ## LightGBMのハイパーパラメータ調整

# %%
params = {
    "metric": "auc",
    "objective": "binary",
    #'force_col_wise': True
}

# %%
auc_ave = []
best_params = []
models = []

for train_index, valid_index in kf.split(data):
    
    X_train = data.iloc[train_index]
    X_valid = data.iloc[valid_index]
    
    y_train = target.iloc[train_index]
    y_valid = target.iloc[valid_index]
    
    lgb_train = lgb_o.Dataset(X_train, y_train)
    lgb_eval = lgb_o.Dataset(X_valid, y_valid)
    
    lgbm = lgb_o.train(
        params,
        lgb_train,
        valid_sets=lgb_eval,
        num_boost_round=1000,
        early_stopping_rounds=50,
        verbose_eval=False
    )
    
    #y_train_pred = lgbm.predict(x_train)
    y_pred = lgbm.predict(X_valid)
    
    auc = roc_auc_score(y_valid, y_pred)
    auc_ave.append(auc)
    
    best_params.append(lgbm.params)
    
    models.append(lgbm)
    
    print(auc)

print("ave:{:.3f}".format(np.mean(auc_ave)))
# Out:
# [I 2024-01-18 13:27:26,465] A new study created in memory with name: no-name-6c300236-5232-4bcf-9c29-c31f80df8cfb
# feature_fraction, val_score: -inf:   0%|                                                         | 0/7 [00:00<?, ?it/s]
# [LightGBM] [Info] Number of positive: 143, number of negative: 211
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000165 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 158
# [LightGBM] [Info] Number of data points in the train set: 354, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.403955 -> initscore=-0.389014
# [LightGBM] [Info] Start training from score -0.389014
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# feature_fraction, val_score: 0.939305:   0%|                                                     | 0/7 [00:00<?, ?it/s][I 2024-01-18 13:27:26,530] Trial 0 finished with value: 0.9393048128342246 and parameters: {'feature_fraction': 1.0}. Best is trial 0 with value: 0.9393048128342246.
# feature_fraction, val_score: 0.948128:  14%|######4                                      | 1/7 [00:00<00:00, 10.30it/s][I 2024-01-18 13:27:26,577] Trial 1 finished with value: 0.9481283422459893 and parameters: {'feature_fraction': 0.6}. Best is trial 1 with value: 0.9481283422459893.
# feature_fraction, val_score: 0.948128:  43%|###################2                         | 3/7 [00:00<00:00, 23.19it/s][I 2024-01-18 13:27:26,608] Trial 2 finished with value: 0.9475935828877006 and parameters: {'feature_fraction': 0.8}. Best is trial 1 with value: 0.9481283422459893.
# feature_fraction, val_score: 0.948128:  43%|###################2                         | 3/7 [00:00<00:00, 23.19it/s]
# [LightGBM] [Info] Number of positive: 143, number of negative: 211
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000143 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 158
# [LightGBM] [Info] Number of data points in the train set: 354, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.403955 -> initscore=-0.389014
# [LightGBM] [Info] Start training from score -0.389014
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 143, number of negative: 211
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000124 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 158
# [LightGBM] [Info] Number of data points in the train set: 354, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.403955 -> initscore=-0.389014
# [LightGBM] [Info] Start training from score -0.389014
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 143, number of negative: 211
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000110 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 158
# [LightGBM] [Info] Number of data points in the train set: 354, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.403955 -> initscore=-0.389014
# [LightGBM] [Info] Start training from score -0.389014
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [I 2024-01-18 13:27:26,662] Trial 3 finished with value: 0.9454545454545454 and parameters: {'feature_fraction': 0.4}. Best is trial 1 with value: 0.9481283422459893.
# feature_fraction, val_score: 0.948128:  57%|#########################7                   | 4/7 [00:00<00:00, 23.19it/s][I 2024-01-18 13:27:26,707] Trial 4 finished with value: 0.9438502673796791 and parameters: {'feature_fraction': 0.8999999999999999}. Best is trial 1 with value: 0.9481283422459893.
# feature_fraction, val_score: 0.948128:  71%|################################1            | 5/7 [00:00<00:00, 23.19it/s]
# [LightGBM] [Info] Number of positive: 143, number of negative: 211
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003112 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 158
# [LightGBM] [Info] Number of data points in the train set: 354, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.403955 -> initscore=-0.389014
# [LightGBM] [Info] Start training from score -0.389014
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# feature_fraction, val_score: 0.948128:  86%|######################################5      | 6/7 [00:00<00:00, 22.81it/s][I 2024-01-18 13:27:26,741] Trial 5 finished with value: 0.9481283422459893 and parameters: {'feature_fraction': 0.5}. Best is trial 1 with value: 0.9481283422459893.
# feature_fraction, val_score: 0.950802:  86%|######################################5      | 6/7 [00:00<00:00, 22.81it/s][I 2024-01-18 13:27:26,777] Trial 6 finished with value: 0.9508021390374332 and parameters: {'feature_fraction': 0.7}. Best is trial 6 with value: 0.9508021390374332.
# feature_fraction, val_score: 0.950802: 100%|#############################################| 7/7 [00:00<00:00, 23.28it/s]
# [LightGBM] [Info] Number of positive: 143, number of negative: 211
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000143 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 158
# [LightGBM] [Info] Number of data points in the train set: 354, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.403955 -> initscore=-0.389014
# [LightGBM] [Info] Start training from score -0.389014
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 143, number of negative: 211
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000143 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 158
# [LightGBM] [Info] Number of data points in the train set: 354, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.403955 -> initscore=-0.389014
# [LightGBM] [Info] Start training from score -0.389014
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# num_leaves, val_score: 0.950802:   0%|                                                          | 0/20 [00:00<?, ?it/s][I 2024-01-18 13:27:26,812] Trial 7 finished with value: 0.9508021390374332 and parameters: {'num_leaves': 195}. Best is trial 7 with value: 0.9508021390374332.
# num_leaves, val_score: 0.950802:   5%|##5                                               | 1/20 [00:00<00:01, 16.14it/s][I 2024-01-18 13:27:26,844] Trial 8 finished with value: 0.9508021390374332 and parameters: {'num_leaves': 141}. Best is trial 7 with value: 0.9508021390374332.
# num_leaves, val_score: 0.950802:  10%|#####                                             | 2/20 [00:00<00:00, 30.79it/s]
# [LightGBM] [Info] Number of positive: 143, number of negative: 211
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000085 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 158
# [LightGBM] [Info] Number of data points in the train set: 354, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.403955 -> initscore=-0.389014
# [LightGBM] [Info] Start training from score -0.389014
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# min_data_in_leaf, val_score: 0.803857:  80%|####################################         | 4/5 [00:00<00:00, 16.91it/s][I 2024-01-18 13:27:47,167] Trial 66 finished with value: 0.7889807162534436 and parameters: {'min_child_samples': 25}. Best is trial 66 with value: 0.7889807162534436.
# min_data_in_leaf, val_score: 0.803857:  80%|####################################         | 4/5 [00:00<00:00, 16.91it/s][I 2024-01-18 13:27:47,191] Trial 67 finished with value: 0.7506887052341598 and parameters: {'min_child_samples': 50}. Best is trial 66 with value: 0.7889807162534436.
# min_data_in_leaf, val_score: 0.803857: 100%|#############################################| 5/5 [00:00<00:00, 18.88it/s]
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Number of positive: 144, number of negative: 211
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000117 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 157
# [LightGBM] [Info] Number of data points in the train set: 355, number of used features: 9
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.405634 -> initscore=-0.382045
# [LightGBM] [Info] Start training from score -0.382045
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 0.8038567493112948
# ave:0.893

# %%
best_params
# Out:
# [{'metric': 'auc',
#   'objective': 'binary',
#   'feature_pre_filter': False,
#   'lambda_l1': 0.014955489930001849,
#   'lambda_l2': 2.2910008571358935e-06,
#   'num_leaves': 11,
#   'feature_fraction': 0.7,
#   'bagging_fraction': 0.7008070212902303,
#   'bagging_freq': 5,
#   'min_child_samples': 20,
#   'num_iterations': 1000,
#   'early_stopping_round': 50},
#  {'metric': 'auc',
#   'objective': 'binary',
#   'feature_pre_filter': False,
#   'lambda_l1': 0.03534583683603272,
#   'lambda_l2': 0.004143658996054168,
#   'num_leaves': 31,
#   'feature_fraction': 0.8999999999999999,
#   'bagging_fraction': 0.8849505214185354,
#   'bagging_freq': 7,
#   'min_child_samples': 20,
#   'num_iterations': 1000,
#   'early_stopping_round': 50},
#  {'metric': 'auc',
#   'objective': 'binary',
#   'feature_pre_filter': False,
#   'lambda_l1': 0.0,
#   'lambda_l2': 0.0,
#   'num_leaves': 31,
#   'feature_fraction': 0.6,
#   'bagging_fraction': 1.0,
#   'bagging_freq': 0,
#   'min_child_samples': 20,
#   'num_iterations': 1000,
#   'early_stopping_round': 50},
#  {'metric': 'auc',
#   'objective': 'binary',
#   'feature_pre_filter': False,
#   'lambda_l1': 0.05162833250189203,
#   'lambda_l2': 3.932851976360499e-05,
#   'num_leaves': 31,
#   'feature_fraction': 1.0,
#   'bagging_fraction': 1.0,
#   'bagging_freq': 0,
#   'min_child_samples': 20,
#   'num_iterations': 1000,
#   'early_stopping_round': 50},
#  {'metric': 'auc',
#   'objective': 'binary',
#   'feature_pre_filter': False,
#   'lambda_l1': 0.006034879458372983,
#   'lambda_l2': 1.9321205747980522e-07,
#   'num_leaves': 31,
#   'feature_fraction': 0.8999999999999999,
#   'bagging_fraction': 0.8563949742936017,
#   'bagging_freq': 3,
#   'min_child_samples': 20,
#   'num_iterations': 1000,
#   'early_stopping_round': 50}]

# %% [markdown]
# ## 提出データの作成

# %%
le = LabelEncoder()
test["sex"] = le.fit_transform(test["sex"])
le.classes_
# Out:
# array(['female', 'male'], dtype=object)

# %%
le = LabelEncoder()
test["embarked"] = le.fit_transform(test["embarked"])
le.classes_
# Out:
# array(['C', 'Q', 'S'], dtype=object)

# %%
test["age"] = test["age"].fillna(train["age"].mean())

# %%
test["age_label"] = pd.cut(test["age"], bins=bins, labels=False)

# %%
test["family"] = test["sibsp"] + test["parch"] +1

# %%
test
# Out:
#      pclass  sex        age  sibsp  parch     fare  embarked  age_label
# id
# 0         3    1  22.000000      1      0   7.2500         2          1  \
# 1         1    0  38.000000      1      0  71.2833         0          1
# 2         3    0  26.000000      0      0   7.9250         2          1
# 5         3    1  29.095447      0      0   8.4583         1          1
# 6         1    1  54.000000      0      0  51.8625         2          2
# ..      ...  ...        ...    ...    ...      ...       ...        ...
# 885       3    0  39.000000      0      5  29.1250         1          1
# 886       2    1  27.000000      0      0  13.0000         2          1
# 887       1    0  19.000000      0      0  30.0000         2          0
# 889       1    1  26.000000      0      0  30.0000         0          1
# 890       3    1  32.000000      0      0   7.7500         1          1
#
#      family
# id
# 0         2
# 1         2
# 2         1
# 5         1
# 6         1
# ..      ...
# 885       6
# 886       1
# 887       1
# 889       1
# 890       1
#
# [446 rows x 9 columns]

# %%
i = 0
df_submit = pd.DataFrame([])
for m in models:
    y_submit = m.predict(test)
    df_submit[i] = y_submit
    i+=1

# %%
df_submit
# Out:
#             0         1         2         3         4
# 0    0.109581  0.060002  0.030493  0.307286  0.023982
# 1    0.926178  0.975642  0.998223  0.545786  0.991446
# 2    0.574585  0.573191  0.512331  0.439533  0.598901
# 3    0.240236  0.306811  0.077071  0.364926  0.758567
# 4    0.325768  0.324322  0.241350  0.393813  0.298218
# ..        ...       ...       ...       ...       ...
# 441  0.376733  0.288000  0.161493  0.467680  0.198110
# 442  0.216339  0.162651  0.115171  0.364926  0.078614
# 443  0.809464  0.937089  0.989740  0.552317  0.985746
# 444  0.511111  0.520826  0.715825  0.393813  0.786677
# 445  0.216365  0.179964  0.154518  0.318913  0.092299
#
# [446 rows x 5 columns]

# %%
df_submit["ave"] = df_submit.mean(axis=1)
df_submit.head()
# Out:
#           0         1         2         3         4       ave
# 0  0.109581  0.060002  0.030493  0.307286  0.023982  0.106269
# 1  0.926178  0.975642  0.998223  0.545786  0.991446  0.887455
# 2  0.574585  0.573191  0.512331  0.439533  0.598901  0.539708
# 3  0.240236  0.306811  0.077071  0.364926  0.758567  0.349522
# 4  0.325768  0.324322  0.241350  0.393813  0.298218  0.316694

# %%
sample_submit
# Out:
#      1
# 0
# 0    0
# 1    1
# 2    0
# 5    1
# 6    1
# ..  ..
# 885  1
# 886  1
# 887  1
# 889  1
# 890  0
#
# [446 rows x 1 columns]

# %%
df_submit.index = sample_submit.index
df_submit
# Out:
#             0         1         2         3         4       ave
# 0
# 0    0.109581  0.060002  0.030493  0.307286  0.023982  0.106269
# 1    0.926178  0.975642  0.998223  0.545786  0.991446  0.887455
# 2    0.574585  0.573191  0.512331  0.439533  0.598901  0.539708
# 5    0.240236  0.306811  0.077071  0.364926  0.758567  0.349522
# 6    0.325768  0.324322  0.241350  0.393813  0.298218  0.316694
# ..        ...       ...       ...       ...       ...       ...
# 885  0.376733  0.288000  0.161493  0.467680  0.198110  0.298403
# 886  0.216339  0.162651  0.115171  0.364926  0.078614  0.187540
# 887  0.809464  0.937089  0.989740  0.552317  0.985746  0.854871
# 889  0.511111  0.520826  0.715825  0.393813  0.786677  0.585650
# 890  0.216365  0.179964  0.154518  0.318913  0.092299  0.192412
#
# [446 rows x 6 columns]

# %%
df_submit["ave"].to_csv('submit_lightgbm_model.tsv', header=None, sep='\t')
